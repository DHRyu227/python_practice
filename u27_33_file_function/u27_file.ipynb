# %% [markdown]
# # 27 문자열

# %%
with open('hello.txt', 'w') as file:
    for i in range(3):
        file.write('Hello, world! {0}\n'. format(i))

# %%
lines = ['안녕하세요.\n', '파이썬\n', '코딩 도장입니다.\n']

with open('hello.txt', 'w') as file:
    file.writelines(lines)

# %% [markdown]
# - cat은 unix 명령어 (window에서는 type)

# %%
# !cat hello.txt
# Out:
# 안녕하세요.
# 파이썬
# 코딩 도장입니다.

# %%
file = open('hello.txt') # 'r' mode가 default
s = file.read()
print(s)
file.close()
# Out:
# 안녕하세요.
# 파이썬
# 코딩 도장입니다.

# %%
# 파이썬 스타일
with open('hello.txt') as file:
    s = file.read()
print(s)
# Out:
# 안녕하세요.
# 파이썬
# 코딩 도장입니다.

# %% [markdown]
# ## 27.2 문자열 여러줄

# %%
with open('hello.txt') as file:
    s = file.readline()
print(s)
# Out:
# 안녕하세요.

# %%
with open('hello.txt') as file:
    line = None
    while line != '':
        line = file.readline()
        print(line.strip('\n'))
# Out:
# 안녕하세요.
# 파이썬
# 코딩 도장입니다.

# %%
with open('hello.txt') as file:
    for line in file:
        print(line.strip('\n'))
# Out:
# 안녕하세요.
# 파이썬
# 코딩 도장입니다.

# %% [markdown]
# - \_\_iter\_\_ 가 정의되어 있으면 for 문 사용 가능

# %%
with open('hello.txt') as file:
    s = file.read(9)
print(s)
# Out:
# 안녕하세요.
# 파이

# %% [markdown]
# ### append

# %%
with open('hello.txt', 'a') as file:
    file.write('Append\n')

# %%
# !cat hello.txt
# Out:
# 안녕하세요.
# 파이썬
# 코딩 도장입니다.
# Append

# %% [markdown]
# ### binary mode

# %%
with open('chairs.jpg', 'rb') as bin:
    x = bin.read(10)
print(x)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-e1b4eba9b36e> in <module>()
# ----> 1 with open('chairs.jpg', 'rb') as bin:
#       2     x = bin.read(10)
#       3
#       4 print(x)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'chairs.jpg'

# %% [markdown]
# ## 27.3 파이썬 객체 읽고 쓰기

# %%
import pickle

scores = {'kor':90, 'eng':90, 'mat':80}
with open('binary.pkl', 'wb') as file:
    pickle.dump(scores, file)

# %%
# !cat binary.pkl
# Out:
# �}q(XkorqKZXengqKZXmatqKPu.

# %%
with open('binary.pkl', 'rb') as file:
    new_scores = pickle.load(file)

new_scores
# Out:
# {'eng': 90, 'kor': 90, 'mat': 80}

# %%
from IPython.display import Image
img = 'https://dojang.io/pluginfile.php/13766/mod_page/content/3/027004.png'
Image(url = img, width=800, height=600)
# Out:
# <img src="https://dojang.io/pluginfile.php/13766/mod_page/content/3/027004.png" width="800" height="600"/>

# %% [markdown]
# # 27.6 심사문제
#
# - 문자열이 저장된 words.txt 파일이 주어집니다(문자열은 한 줄로 저장되어 있습니다). words.txt 파일에서 문자 c가 포함된 단어를 각 줄에 출력하는 프로그램을 만드세요. 단어를 출력할 때는 등장한 순서대로 출력해야 하며 ,(콤마)와 .(점)은 출력하지 않아야 합니다.

# %%
text = "Fortunately, however, for the reputation of Asteroid B-612, a Turkish dictator made a law that his subjects, under pain of death, should change to European costume. So in 1920 the astronomer gave his demonstration all over again, dressed with impressive style and elegance. And this time everybody accepted his report."
with open('test27.txt', 'w') as file:
    file.write(text)

with open('test27.txt') as file:
    s = file.read().split()
    for i in s:
        if i.find('c') != -1:
            if (i.find('.') != -1) | (i.find(',') != -1):
                print(i[:-1])
            else:
                print(i)
# Out:
# dictator
# subjects
# change
# costume
# elegance
# accepted

# %%
text = "Fortunately, however, for the reputation of Asteroid B-612, a Turkish dictator made a law that his subjects, under pain of death, should change to European costume. So in 1920 the astronomer gave his demonstration all over again, dressed with impressive style and elegance. And this time everybody accepted his report."
with open('test27.txt', 'w') as file:
    file.write(text)

with open('test27.txt') as file:
    s = file.read().split()
    for i in s:
        if i.find('c') != -1:
            print(i.strip(',.'))
# Out:
# dictator
# subjects
# change
# costume
# elegance
# accepted
